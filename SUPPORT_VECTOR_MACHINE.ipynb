# %% [markdown]
# <a href="https://colab.research.google.com/github/IsagiTegaYoichi/Sentiment-Analysis-and-Topic-modelling-of-COVID-Vaccine-tweets2/blob/main/SUPPORT_VECTOR_MACHINE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Library to read Data
# !pip install tweet-preprocessor
import pandas as pd
import preprocessor as p
from sklearn.metrics import confusion_matrix
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()




#Read Extraction data
testdata=pd.read_csv('look.csv')

def preprocess_tweet(text):
    text = p.clean(text)
    return text


tokenized_tweet2=testdata['Tweet'].apply(lambda x: x.split())
tokenized_tweet2.head()
tokenized_tweet2=tokenized_tweet2.apply(lambda x:[lemmatizer.lemmatize(i) for i in x])
tokenized_tweet2.head()
stopped=['Follow','vaccine','covid','amp','amp','amp','Vaccine','people','People']
tokenized_tweet2=tokenized_tweet2.apply(lambda x: [item for item in x if item not in stopped])
tokenized_tweet2.head()
for i in range(len(tokenized_tweet2)):
    tokenized_tweet2[i]=' '.join(tokenized_tweet2[i])
testdata['Tweet']=tokenized_tweet2
testdata[['Tweet']].head()
#Import Libraries
from sklearn.feature_extraction.text import TfidfVectorizer
#VECTORIZING THE DATASET
vectorizer= TfidfVectorizer(max_features=5000)
tfidf_matrix=vectorizer.fit_transform(testdata['Tweet'])
tfidf_matrix
x=tfidf_matrix
y=data['Analysis']
#Import Libraries
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1) # 70% training and 30% test
from sklearn import svm
svc=svm.SVC(kernel='linear',probability=True).fit(X_train,y_train)
y_pred=svc.predict(X_test)
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
print('Confusion matrix\n\n', cm)

print('\nTrue Positives(TP) = ', cm[0,0])

print('\nTrue Negatives(TN) = ', cm[1,1])

print('\nFalse Positives(FP) = ', cm[0,1])

print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Requirement already satisfied: tweet-preprocessor in /usr/local/lib/python3.7/dist-packages (0.6.0)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Accuracy: 0.8511343359673719
# Confusion matrix
#
#  [[ 336  178   96]
#  [  18 1810   66]
#  [  39  187 1193]]
#
# True Positives(TP) =  336
#
# True Negatives(TN) =  1810
#
# False Positives(FP) =  178
#
# False Negatives(FN) =  18

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print('Confusion matrix\n\n', cm)

print('\nTrue Positives(TP) = ', cm[0,0])

print('\nTrue Negatives(TN) = ', cm[1,1])

print('\nFalse Positives(FP) = ', cm[0,1])

print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[ 332  182   96]
#  [  12 1823   59]
#  [  40  178 1201]]
#
# True Positives(TP) =  332
#
# True Negatives(TN) =  1823
#
# False Positives(FP) =  182
#
# False Negatives(FN) =  12

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.55      0.67       610
#      Neutral       0.83      0.96      0.89      1894
#     Positive       0.88      0.84      0.86      1419
#
#     accuracy                           0.85      3923
#    macro avg       0.86      0.78      0.81      3923
# weighted avg       0.85      0.85      0.84      3923
